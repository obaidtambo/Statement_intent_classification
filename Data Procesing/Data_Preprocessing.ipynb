# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# In this notebook I have done the preprocessing of the various data sets needed to complete the classification problem:- Calsasifing sentenves into Emotion statement, News Statement, Greeting/Conversation statement or Review.

# %% [markdown]
# Also We have created a new csv files  of the processed data so as to reduce redundancy.
# All the files are attached with the folder.
# We have added a column called intent_ovr which give the overall Intent of the satatements.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ### Pre Processing for Conversation/greeting Data set -Convo

# %%
import json

basic_corpus = open("conversations.json")

basic_corpus_json = json.load(basic_corpus)
basic_content = basic_corpus_json['sentences']

basic_df = pd.json_normalize(basic_content)

df = basic_df[['text','intent']]
df
# Out:
#                      text      intent
# 0                     yes     yesNode
# 1                 oh yeah     yesNode
# 2                 alright     yesNode
# 3              absolutely     yesNode
# 4           oh absolutely     yesNode
# ...                   ...         ...
# 1314       are you asleep  stillThere
# 1315  have you turned off  stillThere
# 1316     have you stopped  stillThere
# 1317         did you stop  stillThere
# 1318         did you quit  stillThere
#
# [1319 rows x 2 columns]

# %%
# adding column with constant value
# adding column with constant value
df['intent_ovr'] = pd.Series(["convo"for x in range(len(df.index))])
df
# Out:
#                      text      intent intent_ovr
# 0                     yes     yesNode      convo
# 1                 oh yeah     yesNode      convo
# 2                 alright     yesNode      convo
# 3              absolutely     yesNode      convo
# 4           oh absolutely     yesNode      convo
# ...                   ...         ...        ...
# 1314       are you asleep  stillThere      convo
# 1315  have you turned off  stillThere      convo
# 1316     have you stopped  stillThere      convo
# 1317         did you stop  stillThere      convo
# 1318         did you quit  stillThere      convo
#
# [1319 rows x 3 columns]

# %%
# saving the dataframe
df.to_csv('convo_intent.csv')

# %%
# df=df.drop(['intent'], axis=1)

# %%
df
# Out:
#                      text intent_ovr
# 0                     yes      convo
# 1                 oh yeah      convo
# 2                 alright      convo
# 3              absolutely      convo
# 4           oh absolutely      convo
# ...                   ...        ...
# 1314       are you asleep      convo
# 1315  have you turned off      convo
# 1316     have you stopped      convo
# 1317         did you stop      convo
# 1318         did you quit      convo
#
# [1319 rows x 2 columns]

# %% [markdown]
# ### Pre Processing for Review(movie) Data set -review

# %%
# Data.tsv is stored locally in the
# same directory as of this python file
df1 = pd.read_csv('train.tsv',sep = '\t')

df1.shape
# Out:
# (156060, 4)

# %%
# df

# %%
df1=df1.drop(['PhraseId','SentenceId'], axis=1)

# %%
df1.rename(columns = {'Phrase':'text'}, inplace = True)

# adding column with constant value
df1['intent_ovr'] = pd.Series(["review"for x in range(len(df1.index))])
df1.tail()
# saving the dataframe
df1.to_csv('review_intent.csv')

# %%
df1.tail()
# Out:
#                              text  Sentiment intent_ovr
# 156055                  Hearst 's          2     review
# 156056  forced avuncular chortles          1     review
# 156057         avuncular chortles          3     review
# 156058                  avuncular          2     review
# 156059                   chortles          2     review

# %%
# df1=df1.drop(['Sentiment'], axis=1)

# %%
# Quick Two Line Codes
ctr_3=0
i=1
text2=[]
for s in df1['text']:
    # print("text: ",s)
    countOfWords = len(s.split())
    
    if ((countOfWords>=3) and (countOfWords<=12)):
        # print(" here :", countOfWords," text: ", s )
        # df1_cpy=df1.drop([s],inplace = True)
        text2.append(s)
    i=i+1

# %%
df1= pd.DataFrame(text2)
df1.columns=['text']
df1=df1.sample(7000)

# %%
# adding column with constant value
df1['intent_ovr'] = pd.Series(["review"for x in range(len(df1.index))])
df1.tail()
# saving the dataframe
df1.to_csv('review_intent.csv')

# %%
df1
# Out:
#                                                      text intent_ovr
# 0       A series of escapades demonstrating the adage ...     review
# 1       A series of escapades demonstrating the adage ...     review
# 2                                                A series     review
# 3                                                       A     review
# 4                                                  series     review
# ...                                                   ...        ...
# 156055                                          Hearst 's     review
# 156056                          forced avuncular chortles     review
# 156057                                 avuncular chortles     review
# 156058                                          avuncular     review
# 156059                                           chortles     review
#
# [156060 rows x 2 columns]

# %% [markdown]
# ### Pre Processing for Emotion Data set -emotion

# %%
# read text file into pandas DataFrame
df2 = pd.read_csv("train.txt", sep=";" ,header=None, names=["text", "emotion"])

# %%
df2
# Out:
#                                                     text  emotion
# 0                                i didnt feel humiliated  sadness
# 1      i can go from feeling so hopeless to so damned...  sadness
# 2       im grabbing a minute to post i feel greedy wrong    anger
# 3      i am ever feeling nostalgic about the fireplac...     love
# 4                                   i am feeling grouchy    anger
# ...                                                  ...      ...
# 15995  i just had a very brief time in the beanbag an...  sadness
# 15996  i am now turning and i feel pathetic that i am...  sadness
# 15997                     i feel strong and good overall      joy
# 15998  i feel like this was such a rude comment and i...    anger
# 15999  i know a lot but i feel so stupid because i ca...  sadness
#
# [16000 rows x 2 columns]

# %%
# adding column with constant value
df2['intent_ovr'] = pd.Series(["emotion"for x in range(len(df2.index))])
df2
# Out:
#                                                     text  emotion intent_ovr
# 0                                i didnt feel humiliated  sadness    emotion
# 1      i can go from feeling so hopeless to so damned...  sadness    emotion
# 2       im grabbing a minute to post i feel greedy wrong    anger    emotion
# 3      i am ever feeling nostalgic about the fireplac...     love    emotion
# 4                                   i am feeling grouchy    anger    emotion
# ...                                                  ...      ...        ...
# 15995  i just had a very brief time in the beanbag an...  sadness    emotion
# 15996  i am now turning and i feel pathetic that i am...  sadness    emotion
# 15997                     i feel strong and good overall      joy    emotion
# 15998  i feel like this was such a rude comment and i...    anger    emotion
# 15999  i know a lot but i feel so stupid because i ca...  sadness    emotion
#
# [16000 rows x 3 columns]

# %%
# saving the dataframe
df2.to_csv('emotion_intent.csv')

# %%
df2=df2.drop(['emotion'], axis=1)

# %%
df2.tail(10)
# Out:
#                                                     text intent_ovr
# 15990  i feel really glad that i dont look like the c...    emotion
# 15991  i have wanted to perhaps convey my feelings of...    emotion
# 15992  i moved away he said something that made me fe...    emotion
# 15993  i most days feel like if braeden and calvin ar...    emotion
# 15994      i feel so sympathetic empathetic towards them    emotion
# 15995  i just had a very brief time in the beanbag an...    emotion
# 15996  i am now turning and i feel pathetic that i am...    emotion
# 15997                     i feel strong and good overall    emotion
# 15998  i feel like this was such a rude comment and i...    emotion
# 15999  i know a lot but i feel so stupid because i ca...    emotion

# %% [markdown]
# ### Pre Processing for News Statement(Fake and Real) Data set -facts

# %%
# read text file into pandas DataFrame
df3 = pd.read_csv("True.csv")
df3
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
# df3=df3.drop(['text','date'], axis=1)

# %%
df3.rename(columns = {'title':'text'}, inplace = True)

# adding column with constant value
df3['intent_ovr'] = pd.Series(["facts"for x in range(len(df3.index))])
df3
# saving the dataframe
# df3.to_csv('facts_intent.csv')
# Out:
#                                                     text       subject  \
# 0      As U.S. budget fight looms, Republicans flip t...  politicsNews
# 1      U.S. military to accept transgender recruits o...  politicsNews
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...  politicsNews
# 3      FBI Russia probe helped by Australian diplomat...  politicsNews
# 4      Trump wants Postal Service to charge 'much mor...  politicsNews
# ...                                                  ...           ...
# 21412  'Fully committed' NATO backs new U.S. approach...     worldnews
# 21413  LexisNexis withdrew two products from Chinese ...     worldnews
# 21414  Minsk cultural hub becomes haven from authorities     worldnews
# 21415  Vatican upbeat on possibility of Pope Francis ...     worldnews
# 21416  Indonesia to buy $1.14 billion worth of Russia...     worldnews
#
#       intent_ovr
# 0          facts
# 1          facts
# 2          facts
# 3          facts
# 4          facts
# ...

# %%
# saving the dataframe
df3.to_csv('facts_intent.csv')

# %%
# df3=df3.drop(['subject'], axis=1)
# # splitting dataframe by row index
# df_1 = df3.iloc[:10000,:]
# df_2 = df3.iloc[10000:,:]
# print("Shape of new dataframes - {} , {}".format(df_1.shape, df_2.shape))

# %%
df3
# Out:
#                                                     text intent_ovr
# 0      As U.S. budget fight looms, Republicans flip t...      facts
# 1      U.S. military to accept transgender recruits o...      facts
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...      facts
# 3      FBI Russia probe helped by Australian diplomat...      facts
# 4      Trump wants Postal Service to charge 'much mor...      facts
# ...                                                  ...        ...
# 21412  'Fully committed' NATO backs new U.S. approach...      facts
# 21413  LexisNexis withdrew two products from Chinese ...      facts
# 21414  Minsk cultural hub becomes haven from authorities      facts
# 21415  Vatican upbeat on possibility of Pope Francis ...      facts
# 21416  Indonesia to buy $1.14 billion worth of Russia...      facts
#
# [21417 rows x 2 columns]

# %%
# read text file into pandas DataFrame
df4 = pd.read_csv("Fake.csv")
df4
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
df4=df4.drop(['text','date'], axis=1)

# %%
df4.rename(columns = {'title':'text'}, inplace = True)

# adding column with constant value
df4['intent_ovr'] = pd.Series(["facts"for x in range(len(df4.index))])
df4


# saving the dataframe
df4.to_csv('facts2_intent.csv')

# %%
df4=df4.drop(['subject'], axis=1)

# %%
df4=df4.sample(7500)
df4
# # splitting dataframe by row index
# df_f = df4.iloc[:10000,:]
# df_f2 = df4.iloc[10000:,:]
# print("Shape of new dataframes - {} , {}".format(df_f.shape, df_f2.shape))
# Out:
#                                                     text intent_ovr
# 0       Donald Trump Sends Out Embarrassing New Year’...      facts
# 1       Drunk Bragging Trump Staffer Started Russian ...      facts
# 2       Sheriff David Clarke Becomes An Internet Joke...      facts
# 3       Trump Is So Obsessed He Even Has Obama’s Name...      facts
# 4       Pope Francis Just Called Out Donald Trump Dur...      facts
# ...                                                  ...        ...
# 23476  McPain: John McCain Furious That Iran Treated ...      facts
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...      facts
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...      facts
# 23479  How to Blow $700 Million: Al Jazeera America F...      facts
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...      facts
#
# [23481 rows x 2 columns]

# %%
frames = [df, df1, df2,df3,df4]
  
result = pd.concat(frames)
result.shape
# Out:
# (218277, 2)

# %%
result.to_csv('data_project.csv')

# %% [markdown]
# Text Preprocessing

# %%
import numpy as np
import pandas as pd
import re
import nltk
import spacy
import string
pd.options.mode.chained_assignment = None

full_df = pd.read_csv("data_project.csv")
# full_df.head()
full_df.tail(1000)
# Out:
#         Unnamed: 0                                               text  \
# 217277       22481  No Longer a Fantasy: Could Hillary Clinton Act...
# 217278       22482               ‘Is Donald Trump Really the Answer?’
# 217279       22483  Tyranny Of 9/11: The Building Blocks Of The Am...
# 217280       22484  SUNDAY SCREENING: National Security Alert: The...
# 217281       22485  Episode #152 – SUNDAY WIRE: ‘From Ground Zero ...
# ...            ...                                                ...
# 218272       23476  McPain: John McCain Furious That Iran Treated ...
# 218273       23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 218274       23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 218275       23479  How to Blow $700 Million: Al Jazeera America F...
# 218276       23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#        intent_ovr
# 217277      facts
# 217278      facts
# 217279      facts
# 217280      facts
# 217281      facts
# ...

# %%
df = full_df
df["text"] = df["text"].astype(str)
full_df.head()
# Out:
#    Unnamed: 0           text intent_ovr
# 0           0            yes      convo
# 1           1        oh yeah      convo
# 2           2        alright      convo
# 3           3     absolutely      convo
# 4           4  oh absolutely      convo

# %%
df["text"] = df["text"].str.lower()
df.sample(15)
# Out:
#         Unnamed: 0                                               text  \
# 33437        32118                           mr. audiard 's direction
# 62611        61292  you 'd have to be a most hard-hearted person n...
# 203240        8444   watch: ted cruz lies straight to the camera a...
# 103830      102511              's attracting audiences to unfaithful
# 130275      128956                                     larger picture
# 128534      127215                        for self-deprecating comedy
# 160557        3178  i am feeling remotely dignified tasteful or co...
# 96              96                           oh yes i would sometimes
# 102889      101570                                the camera whirls !
# 163199        5820      i want or need to hear to make me feel valued
# 29842        28523  the star who helped give a spark to `` chasing...
# 197762        2966   whoopi goldberg furious over trump’s john lew...
# ...

# %%
# # drop the new column created in last cell
# df.drop(["text_lower"], axis=1, inplace=True)

PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["text_wo_punct"] = df["text"].apply(lambda text: remove_punctuation(text))
df.sample(10)
# Out:
#         Unnamed: 0                                               text  \
# 190275       16896  turkey to allow muftis to conduct weddings, sp...
# 42662        41343                                  the story compels
# 124749      123430         connection or identification frustratingly
# 167829       10450  i took the step to start this blog i feel as t...
# 102441      101122                      rhetoric , which are included
# 41362        40043                                        a telescope
# 207174       12378  oh look! new yorkers don’t hate trump as much ...
# 172540       15161  i feel anxious and worry just in case i dont u...
# 83883        82564                                        severe case
# 204365        9569  republicans call for answers: did wasserman-sc...
#
#        intent_ovr                                      text_wo_punct
# 190275      facts  turkey to allow muftis to conduct weddings spa...
# ...

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["text_wo_stop"] = df["text_wo_punct"].apply(lambda text: remove_stopwords(text))
df.sample(10)
# Out:
#         Unnamed: 0                                               text  \
# 40951        39632                                     is , by itself
# 96046        94727                                        young leads
# 4946          3627                                         new wounds
# 146723      145404  clooney 's -rrb- debut can be accused of being...
# 202432        7636   colin powell bashes gop candidates for ‘belit...
# 172723       15344  i feel more confident already a href http john...
# 153297      151978  their consistently sensitive and often excitin...
# 132621      131302                                    tear their eyes
# 109687      108368  the last kiss will probably never achieve the ...
# 29967        28648                                strong and unforced
#
#        intent_ovr                                      text_wo_punct  \
# 40951      review                                      is  by itself
# ...

# %% [markdown]
# frequent words removal

# %%
from collections import Counter
cnt = Counter()
for text in df["text_wo_stop"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)

# %%
FREQWORDS = set([w for (w, wc) in cnt.most_common(10)])
def remove_freqwords(text):
    """custom function to remove the frequent words"""
    return " ".join([word for word in str(text).split() if word not in FREQWORDS])

df["text_wo_stopfreq"] = df["text_wo_stop"].apply(lambda text: remove_freqwords(text))
df.head()

# %% [markdown]
# Lemetization

# %%
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N":wordnet.NOUN, "V":wordnet.VERB, "J":wordnet.ADJ, "R":wordnet.ADV}
def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

df["text_lemmatized"] = df["text_wo_stop"].apply(lambda text: lemmatize_words(text))
df.head()
# Out:
#    Unnamed: 0           text intent_ovr  text_wo_punct   text_wo_stop  \
# 0           0            yes      convo            yes            yes
# 1           1        oh yeah      convo        oh yeah        oh yeah
# 2           2        alright      convo        alright        alright
# 3           3     absolutely      convo     absolutely     absolutely
# 4           4  oh absolutely      convo  oh absolutely  oh absolutely
#
#   text_lemmatized
# 0             yes
# 1         oh yeah
# 2         alright
# 3      absolutely
# 4   oh absolutely

# %%
df.sample(10)
# Out:
#         Unnamed: 0                                               text  \
# 122712      121393          `` the good girl '' a film worth watching
# 13364        12045                                           humanist
# 30570        29251                         -- to its own detriment --
# 72024        70705  a lot less time trying to make a credible case...
# 162898        5519  i feel useless and gross and cant seem to find...
# 189678       16299  putin, as part of test, oversees launch of fou...
# 17750        16431                                             a ride
# 21652        20333                                          roberts '
# 109417      108098  has become commonplace in movies that explore ...
# 213264       18468  huh? nyt editor blames “republican rage machin...
#
#        intent_ovr                                      text_wo_punct  \
# 122712     review               the good girl  a film worth watching
# ...

# %%
df.to_csv('data_project_processed.csv')
